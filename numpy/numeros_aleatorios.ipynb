# %%
import numpy as np

# %%
np.random.seed(123)
array = np.random.randint(1, 101, 20)
array
# Out:
# array([67, 93, 99, 18, 84, 58, 87, 98, 97, 48, 74, 33, 47, 97, 26, 84, 79,
#        37, 97, 81])

# %%
array = np.random.normal(10, 2, 20)
array
# Out:
# array([ 8.46113306, 11.15349204, 10.25305184,  7.39702205, 14.41485487,
#        11.04548494, 10.93128951, 11.44983045, 12.99165305, 11.49316118,
#         7.79802949,  7.17939759,  8.50469737,  8.03026479,  8.50286264,
#        10.48073455,  6.28872507,  6.44109039,  4.49955147,  9.5316849 ])

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(array)
# Out:
# (array([1., 2., 2., 3., 2., 2., 4., 2., 1., 1.]),
#  array([ 4.49955147,  5.49108181,  6.48261215,  7.47414249,  8.46567283,
#          9.45720317, 10.44873351, 11.44026385, 12.43179419, 13.42332453,
#         14.41485487]),
#  <BarContainer object of 10 artists>)
